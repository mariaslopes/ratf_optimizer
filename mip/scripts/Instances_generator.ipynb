# %%
import numpy as np
import os 
from itertools import permutations

# %%
def write_to_file(directory, round, num_boxes, operations, robotC, file_list):
    """
    Write to file:

    round;
    nBoxes = 4;
    L_c = [50, 51, 52, 53];
    n_eta = [0,0,0,0];
    C = robotC;
    """
    file_path = directory + "/R" + str(round) + "_" + operations + "_C" + str(robotC) + ".dat"
    with open(file_path, "w") as file:
        file.write("nBoxes = " + str(num_boxes) + ";\n")
        file.write("L_c = [50, 51, 52, 53];\n")
        file.write("n_eta = ["+ operations[0]+ ","+ operations[1]+ ","+ operations[2]+ ","+ operations[3]+ "];\n")
        file.write("C = "+ str(robotC) + ";")
    
    filename = "Data" + str(round) + "/R" + str(round) + "_" + operations + "_C" + str(robotC) + ".dat"
    file_list.write("\"" + filename + "\",\n")

# %%
# Round 1
capacity = 4
operations = ['0'.zfill(4)]
round = ["1M1", '1M2', '1M3']
directory = "../results/Data1"
if not os.path.exists(directory):
    os.mkdir(directory)

file_list = directory + "/filelist.txt"
with open(file_list, "w") as file:
  for m, model in enumerate(round):
    for cap in range(1, capacity+1):
        for i, code in enumerate(operations):
            write_to_file(directory, model, capacity, str(code), cap, file)

# %%
# Round 2
digits = '1100'
operations = set()
for p in permutations(digits):
  operations.add(''.join(p))

capacity = 4
round = 2
directory = "../results/Data2"
if not os.path.exists(directory):
    os.mkdir(directory)

file_list = directory + "/filelist.txt"
with open(file_list, "w") as file:
  for cap in range(1, capacity+1):
      for i, code in enumerate(operations):
          write_to_file(directory, round, capacity, str(code), cap, file)

# %%
# Round 2 Extras
round = '2E'
operations = ['1110', '1111']
capacity = 2
directory = '../results/Data2E'

if not os.path.exists(directory):
    os.mkdir(directory)

file_list = directory + "/filelist.txt"
with open(file_list, "w") as file:
  for cap in range(1, capacity+1):
      for i, code in enumerate(operations):
          write_to_file(directory, round, capacity, str(code), cap, file)

# %%
# Round 2 with Model 3
digits = '1100'
operations = set()
for p in permutations(digits):
  operations.add(''.join(p))

capacity = 4
round = "2M3"
directory = "../results/Data2M3"
if not os.path.exists(directory):
    os.mkdir(directory)

file_list = directory + "/filelist.txt"
with open(file_list, "w") as file:
  for cap in range(1, capacity+1):
      for i, code in enumerate(operations):
          write_to_file(directory, round, capacity, str(code), cap, file)

# %%
# Round 3
digits = '2110'
operations = set()
for p in permutations(digits):
  operations.add(''.join(p))

capacity = 4
round = 3
directory = "../results/Data3"
if not os.path.exists(directory):
    os.mkdir(directory)

file_list = directory + "/filelist.txt"
with open(file_list, "w") as file:
  for cap in range(1, capacity+1):
      for i, code in enumerate(operations):
          write_to_file(directory, round, capacity, str(code), cap, file)

# %%
# Round 3 Extras
round = '3E'
operations = ['2200', '2210', '2211', '2220', '2221', '2222']
capacity = 1
directory = '../results/Data3E'

if not os.path.exists(directory):
    os.mkdir(directory)

file_list = directory + "/filelist.txt"
with open(file_list, "w") as file:
  for cap in range(1, capacity+1):
      for i, code in enumerate(operations):
          write_to_file(directory, round, capacity, str(code), cap, file)
