# %%
import csv
import re
import pandas as pd
from itertools import permutations
import matplotlib.pyplot as plt
from pathlib import Path

# %%
def binary2string(input_string):
    output_string = ''
    for char in input_string:
        if char == '0':
            output_string += 'B'
        elif char == '1':
            output_string += 'G'
        elif char == '2':
            output_string += 'R'
    return output_string

def read_file(directory, round, operations,capacity):
    data = []
    filename = directory + str(round) + "_" + str(operations) + "_C" + str(capacity) + ".dat_res.txt"
    data.append(capacity)

    try:
      with open(filename, 'r') as file:
          lines = file.readlines()
    except FileNotFoundError:
      return None

    sequence = []
    for line_number, line in enumerate(lines[:-1], start=1):
        if line_number <= 5:
            parts = line.strip().split('=')
            data.append(float(parts[1].strip()))
        else:
            match = re.search(r'location = (\d+)', line)
            sequence.append(int(match.group(1)))

    data.append(sequence)
    return data

def make_table(rounds, capacity, operations, directory, file_name):
    index = []
    file_path = directory + file_name
    table_data = []

    for r , name in enumerate(rounds):
        for i, code in enumerate(operations):
            for c in range (1 , capacity +1) :
                data = read_file(directory, name, code, c)
                if data is not None:
                    index.append(binary2string(code))
                    table_data.append(pd.Series(data))


    dt = pd.DataFrame(table_data, index = index)
    dt = dt.rename(columns={
        0: 'Capacity',
        1: 'TimeToSolve',
        2: 'Objective',
        3: 'Movements',
        4: 'Gap',
        5: 'LowerBound',
        6: 'Sequence'
    })

    dt.to_csv(file_path)
    return dt

# %%
# Round1
round = ['R1']
operations = ['0'.zfill(4)]
max_capacity = 4
directory = '../results/Data1/'
file = "R1.csv"
R1 = make_table(round, max_capacity, operations, directory, file)

# %%
# Round2
digits = '1100'
operations = set()
for p in permutations(digits):
    operations.add(''.join(p))

round = ['R2']
max_capacity = 4
directory = '../results/Data2/'
file = "R2.csv"
R2 = make_table(round, max_capacity, operations, directory, file)

# %%
# Round 2 extra cases
round = ['R2E']
operations = ['1110', '1111']
max_capacity = 2
directory = '../results/Data2E/'
file = "R2E.csv"
R2E = make_table(round, max_capacity, operations, directory, file)

# %%
# Round 2 with round 3 rules
digits = '1100'
operations = set()
for p in permutations(digits):
    operations.add(''.join(p))

round = ['R2M3']
max_capacity = 4
directory = '../results/Data2M3/'
file = "R2M3.csv"
R2M3 = make_table(round, max_capacity, operations, directory, file)

# %%
# Round 3
digits = '2110'
operations = set()
for p in permutations(digits):
    operations.add(''.join(p))

round = ['R3']
max_capacity = 4
directory = '../results/Data3/'
file = "R3.csv"
R3 = make_table(round, max_capacity, operations, directory, file)

# %%
# Round 3 extra cases
round = ['R3E']
operations = ['2200', '2210', '2211', '2220', '2221', '2222']
max_capacity = 1
directory = '../results/Data3E/'
file = "R3E.csv"
R3E = make_table(round, max_capacity, operations, directory, file)

# %% [markdown]
# # Statistics

# %%
meanM2 = R2['TimeToSolve'].mean()
meanM3 =R2M3['TimeToSolve'].mean()

# %%
mean_values_R2 = R2.groupby('Capacity')['TimeToSolve'].mean()
mean_values_R2M3 = R2M3.groupby('Capacity')['TimeToSolve'].mean()

plt.figure(figsize=(10, 5))
plt.plot(mean_values_R2.index, mean_values_R2, label='Round 2 rules', color='blue', marker='o')
plt.plot(mean_values_R2M3.index, mean_values_R2M3, label='Round 3 rules', color='red', marker='o')
plt.xlabel('Capacity')
plt.ylabel('Mean TimeToSolve')
plt.legend()
plt.grid(True)
plt.xticks(range(int(min(mean_values_R2.index)), int(max(mean_values_R2.index)) + 1))
plt.show()

# %%
mean_values_R2 = R2.groupby('Capacity')['TimeToSolve'].mean()
mean_values_R2M3 = R2M3.groupby('Capacity')['TimeToSolve'].mean()

plt.figure(figsize=(10, 5.7))
plt.boxplot([group['TimeToSolve'] for _, group in R2.groupby('Capacity')], positions=mean_values_R2.index , patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.scatter(mean_values_R2.index - 0.2, mean_values_R2, color='lightblue', label='Round 2 rules')

plt.boxplot([group['TimeToSolve'] for _, group in R2M3.groupby('Capacity')], positions=mean_values_R2M3.index , patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.scatter(mean_values_R2M3.index + 0.2, mean_values_R2M3, color='lightgreen', label='Round 3 rules')

plt.xlabel('Capacity')
plt.ylabel('Time to solve')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

mean_values = R3.groupby('Capacity')[['Gap', 'TimeToSolve']].mean()
std_values = R3.groupby('Capacity')[['Gap', 'TimeToSolve']].std()

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.boxplot([group['Gap'] for _, group in R3.groupby('Capacity')], positions=mean_values.index, patch_artist=True, boxprops=dict(facecolor='lightgreen'),showmeans=True)
plt.ylabel('Gap')
plt.grid()

plt.subplot(1, 2, 2)
plt.boxplot([group['TimeToSolve'] for _, group in R3.groupby('Capacity')], positions=mean_values.index, patch_artist=True, boxprops=dict(facecolor='lightblue'),showmeans=True)
plt.xlabel('Capacity')
plt.ylabel('TimeToSolve')
plt.grid()

plt.tight_layout()
plt.show()

# %%
total_cases = R3.groupby('Capacity').size()

unfinished_cases = R3[R3['Gap'].round(2) > 0]

unfinished_counts = unfinished_cases.groupby('Capacity').size()

unfinished_counts = unfinished_counts.reindex(total_cases.index, fill_value=0)

plt.figure(figsize=(10, 6))
unfinished_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.xlabel('Capacity')
plt.ylabel('Number of Truncated Instances')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Grid search
for i in range(1,4):
  directory_path = Path("../results/grid_search/C="+str(i))

  data_dict = {}
  for file_path in directory_path.iterdir():
      if file_path.is_file():
        filename_wo_ext = file_path.name.rsplit('.', 1)[0]
        parts = filename_wo_ext.split('_')

        method_name = parts[0]
        operation_1 = parts[1]
        operation_2 = parts[2]

        operation_1_cleaned = operation_1.replace('f.', '')
        operation_2_cleaned = operation_2.replace('f.', '')

        try:
          with open(file_path, 'r') as file:
              lines = file.readlines()
        except FileNotFoundError:
            pass

        for line_number, line in enumerate(lines[:-1], start=1):
          if line_number == 1:
              parts = line.strip().split('=')
              data =(float(parts[1].strip()))
              key = (operation_1_cleaned, operation_2_cleaned,method_name)
              data_dict[key] = data

  df = pd.DataFrame(list(data_dict.items()), columns=['Operations', 'Value'])

  df[['Operation_1', 'Operation_2', 'Method']] = pd.DataFrame(df['Operations'].tolist(), index=df.index)
  df.drop(columns=['Operations'], inplace=True)

  df_sorted = df.sort_values(by='Value')
  print(df_sorted[0:10])
  df_sorted[0:10].to_csv("../results/grid_search/C="+str(i)+"_TOP10.csv")
  df_sorted.to_csv("../results/grid_search/C="+str(i)+"_All_ordered.csv")
  methods = df_sorted['Method'].unique()

  dfs = {}
  for method in methods:
      df_method = df_sorted[df_sorted['Method'] == method].pivot(index='Operation_1', columns='Operation_2', values='Value')
      dfs[method] = df_method

  for method, df_method in dfs.items():
      df_method.to_csv("../results/grid_search/"+method+"_C="+str(i)+".csv")
# Out:
#      Value                    Operation_1                         Operation_2  \
# 116  1.192  selectSmallest(regretOnMin())             selectSmallest(value())
# 76   1.193    selectSmallest(domainMin())  selectSmallest(valueSuccessRate())
# 115  1.198  selectSmallest(regretOnMin())                 selectRandomValue()
# 74   1.211    selectSmallest(domainMin())             selectSmallest(value())
# 73   1.212    selectSmallest(domainMin())                 selectRandomValue()
# 112  1.212  selectSmallest(regretOnMin())              selectLargest(value())
# 72   1.221    selectSmallest(domainMin())   selectLargest(valueSuccessRate())
# 69   1.221    selectSmallest(domainMax())  selectSmallest(valueSuccessRate())
# 118  1.222  selectSmallest(regretOnMin())  selectSmallest(valueSuccessRate())
# 70   1.230    selectSmallest(domainMin())              selectLargest(value())
#
#               Method
# 116  IterativeDiving
# 76   IterativeDiving
# 115  IterativeDiving
# 74   IterativeDiving
# 73   IterativeDiving
# 112  IterativeDiving
# 72   IterativeDiving
# 69   IterativeDiving
# 118  IterativeDiving
# 70   IterativeDiving
#       Value                    Operation_1  \
# 180  20.735    selectSmallest(domainMin())
# 182  20.863    selectSmallest(domainMin())
# 177  20.890    selectSmallest(domainMin())
# 178  20.898    selectSmallest(domainMin())
# 181  20.898    selectSmallest(domainMin())
# 213  20.931  selectSmallest(regretOnMin())
# 173  20.941    selectSmallest(domainMax())
# 179  20.956    selectSmallest(domainMin())
# 217  20.968  selectSmallest(regretOnMin())
# 214  20.995  selectSmallest(regretOnMin())
#
#                             Operation_2   Method
# 180             selectSmallest(value())  Restart
# 182  selectSmallest(valueSuccessRate())  Restart
# 177              selectLargest(value())  Restart
# 178        selectLargest(valueImpact())  Restart
# 181       selectSmallest(valueImpact())  Restart
# 213              selectLargest(value())  Restart
# 173   selectLargest(valueSuccessRate())  Restart
# 179   selectLargest(valueSuccessRate())  Restart
# 217       selectSmallest(valueImpact())  Restart
# 214        selectLargest(valueImpact())  Restart
#       Value                    Operation_1  \
# 15   74.120        selectLargest(impact())
# 9    74.205     selectLargest(domainMin())
# 99   76.753  selectSmallest(successRate())
# 16   80.333        selectLargest(impact())
# 11   80.689     selectLargest(domainMin())
# 101  80.785  selectSmallest(successRate())
# 10   80.852     selectLargest(domainMin())
# 100  80.862  selectSmallest(successRate())
# 17   81.046        selectLargest(impact())
# 6    81.320     selectLargest(domainMin())
#
#                             Operation_2           Method
# 15              selectSmallest(value())  IterativeDiving
# 9               selectSmallest(value())  IterativeDiving
# 99              selectSmallest(value())  IterativeDiving
# 16        selectSmallest(valueImpact())  IterativeDiving
# 11   selectSmallest(valueSuccessRate())  IterativeDiving
# 101  selectSmallest(valueSuccessRate())  IterativeDiving
# 10        selectSmallest(valueImpact())  IterativeDiving
# 100       selectSmallest(valueImpact())  IterativeDiving
# 17   selectSmallest(valueSuccessRate())  IterativeDiving
# 6                selectLargest(value())  IterativeDiving
